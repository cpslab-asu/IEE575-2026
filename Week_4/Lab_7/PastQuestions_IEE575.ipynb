# %% [markdown]
# # Instructions
#
#
#
# *   All the questions for the test will be provided in a Python Notebook which will be uploaded in the Lab Repository before the exam time:
# You will be expected to run the notebook in Google Colab since it helps us avoid setup and installation issues.
# *   There will be questions that require coding or justification. You are expected to code and justify your approach within the Python notebook. Specifically you test will be in three parts:
#     *   Plotting and analysis of multivariate distributions (35 Points)
#     *   Gaussian Process Regression in 1d (35 Points)
#     *   Gaussian Process Regression in 2d (30 Points)
# *   You will have approximately 75 minutes for the exam including submission of the files on Canvas and the test will be for a total of 100 points. The breakdown of the points is provided as shown below.
# *   Please ensure you arrive on time to make sure you have everything set up.
# *   This is an Open Internet test. You must refrain from using ChatGPT, DeepSeek, etc., for generating your answers.
# *   Please go through the submission details.
#
# ---

# %% [markdown]
# ## Submission Details:
#
# Once you have completed your test, you will upload two files in the `Module 3 Quiz Work Upload` link.
#
# (`Go to Modules -> Exam Spring 2025 Instructions and uploads -> Module 3 Quiz Work Upload`).
#
# You will submit two files:
#   1. Notebook file
#   2. Generated PDF file.
#
# 1. To generate the Notebook File from Google Colab:
#   1. Click on `File`.
#   2. Click on `Download`.
#   3. Click on `Download.ipynb`.
#   4. Save the file with the following name: `IEE575_Module3_<STUDENT_ID>_Notebook`.
#
#   **(Note: This will be saved with the following file extension: .ipynb)**
# 2. To generate the PDF File from Google Colab:
#   1. Click on `File`.
#   2. Click on `Print`.
#   3. Save the file with the following name: `IEE575_Module3_<STUDENT_ID>_Report`.
#   **(Note: This will be saved with the following file extension: .pdf)**
#
# **Note: Do not worry if downloaded `.pdf` file has some viewing errors. I will be going through both the `.pdf` and `.ipynb` files.**
# ---

# %% [markdown]
# ## Points Breakdown:
#
# |Problem | Question |      Concept        | Type | Marks (Total 100 Points) |
# |:--------:|:--------:|:-------------------------:|:----:|:------------------------:|
# |   1   |   1   | Multivariate Distribution | Code |            10            |
# |   1   |   2   | Multivariate Distribution | Text |             5            |
# |   1   |   3   | Multivariate Distribution | Code |            10            |
# |   1   |   4   | Multivariate Distribution | Code |             5            |
# |   1   |   5   | Multivariate Distribution | Text |             5            |
# |   2   |    1  |           1D GPR          | Code |            15            |
# |   2   |    2  |           1D GPR          | Code |            15            |
# |   2   |    3  |           1D GPR          | Text |             5            |
# |   3   |    1  |      Plot 2d Function     | Code |            10            |
# |   3   |   2   |           2D GPR          | Code |             5            |
# |   3   |   3   |           2D GPR          | Code |             5            |
# |   3   |   4   |           2D GPR          | Text |            10            |
#
# ----

# %%
# All packages have been imported for you

import scipy

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from scipy.stats import multivariate_normal
from scipy.stats import norm
from sklearn.gaussian_process.kernels import Matern, RBF
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error


rng = np.random.default_rng(12345)

# %% [markdown]
# # Problem 1: Multivariate distributions (35 points)
#
# Given a set of data generated from bivariate gaussian distribution $\mathcal{N} \sim (\mu, \Sigma)$ where
#
# $$\mu = \begin{bmatrix}1\\2 \end{bmatrix}, \Sigma = \begin{bmatrix}+0.3,\quad-0.6\\-0.6,\quad +2.5\end{bmatrix}$$

# %% [markdown]
# ## Question 1 (10 Points)
#
# ---
#
#
#
# Plot the contour of the joint density function.

# %%
# Code for Question 1A goes in this block.
####### START CODING FROM HERE ##########
mu = [1,2]
sigma = [[0.3, -0.6], [-0.6, 2.5]]

# %% [markdown]
# ## Question 2 (5 Points)
#
# Can you comment on the dependency between the two variables?

# %% [markdown]
# ### Answer Question 2 goes below.
#
# `Answer below the dashed lines`(Double click on the line to add text)
#
# ------------------------------------

# %% [markdown]
# ## Question 3 (10 Points)
#
# Generate 10 samples from the bivariate normal distribution and print the sample mean and sample variance of each component.

# %%
# Code for Question 1.2A goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 4 (5 Points)
#
# Generate 500 samples from the bivariate normal distribution and print the sample mean and sample variance of each component.

# %%
# Code for Question 1.2B goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 5 (5 Points)
#
# What do you notice in terms of sample mean and variance as the number of sample increseas?

# %% [markdown]
# ### Answer Question 5 goes below.
#
# `Answer below the dashed lines` (Double click on the line to add text)
#
# ------------------------------------

# %% [markdown]
# # Problem 2 (35 Points)
#
# You are given a 1d synthetic function which is defined as follows:
#
# $$f(x) = -(x-3)^2 - sin(3x)$$
#
# such that $x \in[0, 10]$
#
# Please use the following kernel `Matern(length_scale_bounds=(1e-2,1e2))` kernel.

# %% [markdown]
# ## Question 1 (15 Points)
#
# Generate 5 equidistant points and fit a GP. **Predict** the results over 1000 equidistant points and **plot** the true function values, mean prediction and the associated uncertainty.

# %%
# Code for Question 2.1 goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 2 (15 Points)
#
# Generate 15 equidistant points and fit a GP. **Predict** the results over 1000 equidistant points and **plot** the true function values, mean prediction and the associated uncertainty.

# %%
# Code for Question 2.2 goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 3 (5 Points)
#
# What difference do you notice in terms of prediction error? Support with code if needed.
# (Hint: You can comment through visual inspection, or you can use mean squared error or mean absolute error to quantitivaely show.)

# %%
# OPTIONAL: Code for Question 2.3 goes in this block.
####### START CODING FROM HERE ##########
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ### Answer Question 3 goes below.
#
# `Answer below the dashed lines`(Double click on the line to add text)
#
# ------------------------------------

# %% [markdown]
# # Problem 3 (30 Points)
#
# You are given a 2d synthetic function which is defined as follows:
#
# $$f(x_1, x_2) = \frac{(x_1^2 + x_2 - 11)^2 + (x_1 + x_2^2 - 7)^2}{800}$$
#
# such that $x_1, x_2 \in[-5,5]$

# %% [markdown]
# ## Question 1 (10 Points)
#
# Plot the surface of the function. Use 50 points per dimension to generate the grids for the plot.

# %%
# Code for Question 3.1 goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 2 (5 Points)
#
# Generate 20 random points and fit a GP. Using the model, plot the prediction on a grid generated by 50 equidistant points per dimension.

# %%
# Code for Question 3.2A goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 3 (5 Points)
#
# Generate 50 random points and fit a GP. Using the model, plot the prediction on a grid generated by 50 equidistant points per dimension.

# %%
# Code for Question 3.2B goes in this block.
####### START CODING FROM HERE ##########

# %% [markdown]
# ## Question 4 (10 Points)
#
# What difference do you notice in terms of prediction error? Support with code if needed.
#
# (Hint: You can comment through visual inspection, or you can use mean squared error or mean absolute error to quantitivaely show.)

# %%
# OPTIONAL: Code for Question 3.4 goes in this block.
####### START CODING FROM HERE ##########
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ### Answer Question 4 goes below.
#
# `Answer below the dashed lines`(Double click on the line to add text)
#
# ------------------------------------

# %%
# Code for Question 4.2 goes in this block.
####### START CODING FROM HERE ##########
